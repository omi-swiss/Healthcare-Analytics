# %%
import os
import pickle
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn import metrics

import sqlalchemy
import snowflake.connector
from sqlalchemy import create_engine
from snowflake.sqlalchemy import *

import Preprocessing
from Preprocessing import preprocess_data

import model_selection 
from model_selection import train_and_save_best_model

import xgboost as xgb
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor


from datetime import datetime, timedelta
import time  
import pytz    
tz_NY = pytz.timezone('Asia/Kolkata')

import warnings
warnings.filterwarnings('ignore')

import joblib

from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso, HuberRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C
from sklearn import metrics
from sklearn.metrics import r2_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
#       2 import pickle
# ----> 3 import pandas as pd
#       4 import numpy as np
#       5 pd.set_option('display.max_rows', 500)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
data = pd.read_csv("Data/health_data.csv")

# %%
# Assuming you have a DataFrame called "data" with the appropriate columns
# Convert "ADMISSION_DATE" and "DISCHARGE_DATE" to datetime format
data['ADMISSION_DATE'] = pd.to_datetime(data['ADMISSION_DATE'])
data['DISCHARGE_DATE'] = pd.to_datetime(data['DISCHARGE_DATE'])

# Create a new DataFrame "base" with the COALESCE transformations
base = data.copy()  # Create a copy of the original DataFrame

base['HOSPITAL_CODE'] = base['HOSPITAL_CODE'].fillna(0)
base['HOSPITAL_TYPE_CODE'] = base['HOSPITAL_TYPE_CODE'].fillna('None')
base['CITY_CODE_HOSPITAL'] = base['CITY_CODE_HOSPITAL'].fillna(0)
base['HOSPITAL_REGION_CODE'] = base['HOSPITAL_REGION_CODE'].fillna('None')
base['AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL'] = base['AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL'].fillna(0)
base['DEPARTMENT'] = base['DEPARTMENT'].fillna('None')
base['WARD_TYPE'] = base['WARD_TYPE'].fillna('None')
base['WARD_FACILITY_CODE'] = base['WARD_FACILITY_CODE'].fillna('None')
base['BED_GRADE'] = base['BED_GRADE'].fillna(0)
base['CITY_CODE_PATIENT'] = base['CITY_CODE_PATIENT'].fillna(0)
base['TYPE_OF_ADMISSION'] = base['TYPE_OF_ADMISSION'].fillna('None')
base['SEVERITY_OF_ILLNESS'] = base['SEVERITY_OF_ILLNESS'].fillna('Minor')
base['VISITORS_WITH_PATIENT'] = base['VISITORS_WITH_PATIENT'].fillna(0)
base['AGE'] = base['AGE'].fillna('None')
base['ADMISSION_DEPOSIT'] = base['ADMISSION_DEPOSIT'].fillna(0)

# Create a new DataFrame "base_with_features" with additional transformations
base_with_features = base.copy()

base_with_features['ADMISSION_YEAR'] = base_with_features['ADMISSION_DATE'].dt.year
base_with_features['ADMISSION_MONTH'] = base_with_features['ADMISSION_DATE'].dt.month
base_with_features['ADMISSION_DAY'] = base_with_features['ADMISSION_DATE'].dt.day
base_with_features['ADMISSION_MONTH_NAME'] = base_with_features['ADMISSION_DATE'].dt.month_name()
base_with_features['ADMISSION_DAY_NAME'] = base_with_features['ADMISSION_DATE'].dt.day_name()
base_with_features['ADMISSION_ILLNESS_COMB'] = base_with_features['TYPE_OF_ADMISSION'] + '-' + base_with_features['SEVERITY_OF_ILLNESS']
base_with_features['ILLNESS_BEDGRADE_COMB'] = base_with_features['SEVERITY_OF_ILLNESS'] + '-' + base_with_features['BED_GRADE'].astype(str)
base_with_features['DEPARTMENT_ILLNESS_COMB'] = base_with_features['DEPARTMENT'] + '-' + base_with_features['SEVERITY_OF_ILLNESS']


base_with_features['LENGTH_OF_STAY'] = (base_with_features['DISCHARGE_DATE'] - base_with_features['ADMISSION_DATE']).dt.days

# Additional categorization using CASE statement
def categorize_stay_duration(row):
    duration = row['LENGTH_OF_STAY']
    if duration <= 7:
        return 'Short Stay'
    elif duration <= 14:
        return 'Medium Stay'
    else:
        return 'Long Stay'

base_with_features['STAY_DURATION'] = base_with_features.apply(categorize_stay_duration, axis=1)

# Now, you have the equivalent Python code for the SQL query with datetime conversion and corrected column name
result = base_with_features.copy()

# You can print or work with the "result" DataFrame as needed
print(result)
# Out:
#         CASE_ID  HOSPITAL_CODE HOSPITAL_TYPE_CODE  CITY_CODE_HOSPITAL  \
# 0             1              8                  c                   3
# 1             3             10                  e                   1
# 2             4             26                  b                   2
# 3             5             26                  b                   2
# 4             6             23                  a                   6
# ...         ...            ...                ...                 ...
# 236699   255877             23                  a                   6
# 236700   255879              3                  c                   3
# 236701   255880              3                  c                   3
# 236702   255882             19                  a                   7
# 236703   255883             14                  a                   1
#
#        HOSPITAL_REGION_CODE  AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL    DEPARTMENT  \
# 0                         Z                                  3  radiotherapy
# 1                         X                                  2    anesthesia
# 2                         Y                                  2  radiotherapy
# 3                         Y                                  2  radiotherapy
# 4                         X                                  2    anesthesia
# ...                     ...                                ...           ...
# 236699                    X                                  3    gynecology
# 236700                    Z                                  3    gynecology
# 236701                    Z                                  3    gynecology
# 236702                    Y                                  4    gynecology
# 236703                    X                                  4    gynecology
#
#        WARD_TYPE WARD_FACILITY_CODE  BED_GRADE  PATIENTID  CITY_CODE_PATIENT  \
# 0              R                  F        2.0      31397                7.0
# 1              S                  E        2.0      31397                7.0
# 2              R                  D        2.0      31397                7.0
# 3              S                  D        2.0      31397                7.0
# 4              S                  F        2.0      31397                7.0
# ...          ...                ...        ...        ...                ...
# 236699         Q                  F        2.0      61421                8.0
# 236700         R                  A        4.0      78312                0.0
# 236701         R                  A        4.0      78312                0.0
# 236702         Q                  C        1.0      88218                8.0
# 236703         Q                  E        2.0     102887                4.0
#
#        TYPE_OF_ADMISSION SEVERITY_OF_ILLNESS  VISITORS_WITH_PATIENT    AGE  \
# 0              Emergency             Extreme                      2  51-60
# 1                 Trauma             Extreme                      2  51-60
# 2                 Trauma             Extreme                      2  51-60
# 3                 Trauma             Extreme                      2  51-60
# 4                 Trauma             Extreme                      2  51-60
# ...                  ...                 ...                    ...    ...
# 236699            Trauma            Moderate                      4   0-10
# 236700         Emergency            Moderate                     15  41-50
# 236701         Emergency            Moderate                     15  41-50
# 236702         Emergency             Extreme                      4  41-50
# 236703            Trauma             Extreme                      4  31-40
#
#         ADMISSION_DEPOSIT ADMISSION_DATE DISCHARGE_DATE  ADMISSION_YEAR  \
# 0                    4911     2022-08-10     2022-08-20            2022
# 1                    4745     2022-09-09     2022-10-19            2022
# 2                    7272     2022-09-22     2022-11-11            2022
# 3                    5558     2022-11-02     2022-12-22            2022
# 4                    4449     2022-09-16     2022-10-06            2022
# ...                   ...            ...            ...             ...
# 236699               4116     2022-08-13     2022-09-12            2022
# 236700               4587     2022-09-16     2022-11-05            2022
# 236701               4241     2022-11-05     2022-12-25            2022
# 236702               3036     2022-08-02     2022-08-22            2022
# 236703               4326     2022-10-09     2022-11-08            2022
#
#         ADMISSION_MONTH  ADMISSION_DAY ADMISSION_MONTH_NAME  \
# 0                     8             10               August
# 1                     9              9            September
# 2                     9             22            September
# 3                    11              2             November
# 4                     9             16            September
# ...                 ...            ...                  ...
# 236699                8             13               August
# 236700                9             16            September
# 236701               11              5             November
# 236702                8              2               August
# 236703               10              9              October
#
#        ADMISSION_DAY_NAME ADMISSION_ILLNESS_COMB ILLNESS_BEDGRADE_COMB  \
# 0               Wednesday      Emergency-Extreme           Extreme-2.0
# 1                  Friday         Trauma-Extreme           Extreme-2.0
# 2                Thursday         Trauma-Extreme           Extreme-2.0
# 3               Wednesday         Trauma-Extreme           Extreme-2.0
# 4                  Friday         Trauma-Extreme           Extreme-2.0
# ...                   ...                    ...                   ...
# 236699           Saturday        Trauma-Moderate          Moderate-2.0
# 236700             Friday     Emergency-Moderate          Moderate-4.0
# 236701           Saturday     Emergency-Moderate          Moderate-4.0
# 236702            Tuesday      Emergency-Extreme           Extreme-1.0
# 236703             Sunday         Trauma-Extreme           Extreme-2.0
#
#        DEPARTMENT_ILLNESS_COMB  LENGTH_OF_STAY STAY_DURATION
# 0         radiotherapy-Extreme              10   Medium Stay
# 1           anesthesia-Extreme              40     Long Stay
# 2         radiotherapy-Extreme              50     Long Stay
# 3         radiotherapy-Extreme              50     Long Stay
# 4           anesthesia-Extreme              20     Long Stay
# ...                        ...             ...           ...
# 236699     gynecology-Moderate              30     Long Stay
# 236700     gynecology-Moderate              50     Long Stay
# 236701     gynecology-Moderate              50     Long Stay
# 236702      gynecology-Extreme              20     Long Stay
# 236703      gynecology-Extreme              30     Long Stay
#
# [236704 rows x 29 columns]

# %%
def check_n_create_model_features(df,feat_list):
    test = pd.DataFrame()
    for col in feat_list:
        if col in df.columns.tolist():
            test[col] = df[col]
        else:
            test[col] = 0
    
    return test

# %%
# Loading the scoring data
score_data = result.copy()
score_data.columns = [col.upper() for col in score_data.columns.tolist()]
    
# Applying the preprocessing steps
score_data_processed = Preprocessing.preprocess_data(score_data)
    
# Applying feature selection
final_feats = pd.read_pickle('MODEL_FEATS.pkl')
score_data_final = check_n_create_model_features(score_data_processed,final_feats)
    
    
# Writing the dataframe to snowflake as a table
#score_data_final = score_data_final.reset_index()
#score_data_table = pd.merge(score_data,score_data_final,on='CASE_ID',how='left')
#status = insert_predictions_to_snowflake_table(score_data_table)

# %%
# Train and Test split
X = score_data_final.drop('LENGTH_OF_STAY',axis=1)
y = score_data_final[['LENGTH_OF_STAY']]
print(X.shape,y.shape)

x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.3,stratify=y,random_state=123)
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (236704, 17) (236704, 1)
# (165692, 17) (165692, 1)
# (71012, 17) (71012, 1)

# %%
import model_selection 
from model_selection import train_and_save_best_model

# %%
train_and_save_best_model(train_and_save_best_model(x_train, y_train, x_test, y_test, "best_regression_model.pkl"))
# Out:
# Model: Linear Regression
# Train R-squared: 0.29
# RMSE: 14.19
# MAE: 3.23
#
# Model: Random Forest Regressor
# Train R-squared: 0.89
# RMSE: 13.96
# MAE: 3.14
#
# Model: XGBoost Regressor
# Train R-squared: 0.46
# RMSE: 12.73
# MAE: 3.00
#
# The best model is: XGBoost Regressor with RMSE: 12.73
# The best model has been saved to best_regression_model.pkl
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Omar Hamzic\Documents\P4 Snowflake Healthcare Analytics Project\Scripting Score_Direct.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Omar%20Hamzic/Documents/P4%20Snowflake%20Healthcare%20Analytics%20Project/Scripting%20Score_Direct.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> train_and_save_best_model(train_and_save_best_model(x_train, y_train, x_test, y_test, "best_regression_model.pkl"))
#
# TypeError: train_and_save_best_model() missing 4 required positional arguments: 'y_train', 'x_test', 'y_test', and 'save_path'

# %%
best_model = joblib.load("best_regression_model.pkl")

# Now, you can use the best model for predictions
model = None  # Initialize the model variable

if isinstance(best_model, LinearRegression):
    model = LinearRegression()
elif isinstance(best_model, RandomForestRegressor):
    model = RandomForestRegressor()
elif isinstance(best_model, xgb.XGBRegressor):
    model = xgb.XGBRegressor()

# %%
if model == xgb.XGBRegressor():
    model.load_model('MODEL_XGB.model')
elif model == LinearRegression():
    model == pickle.load('MODEL_LR.pkl')
elif model == RandomForestRegressor():
    model == pickle.load('MODEL_RF.pkl')

score_data_final['PREDICTED_LOS'] = np.ceil(model.predict(score_data_final.drop('LENGTH_OF_STAY',axis=1)))

# %%
# Writing the dataframe to snowflake as a table
score_data_final = score_data_final.reset_index()
score_data_table = pd.merge(score_data,score_data_final,on='CASE_ID',how='left')

# %%
print(score_data.shape)
score_data.head()
# Out:
# (236704, 24)
#         HOSPITAL_TYPE_CODE CITY_CODE_HOSPITAL HOSPITAL_REGION_CODE  \
# CASE_ID
# 1                        c                  3                    Z
# 3                        e                  1                    X
# 4                        b                  2                    Y
# 5                        b                  2                    Y
# 6                        a                  6                    X
#
#          AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL    DEPARTMENT WARD_TYPE  \
# CASE_ID
# 1                                        3  radiotherapy         R
# 3                                        2    anesthesia         S
# 4                                        2  radiotherapy         R
# 5                                        2  radiotherapy         S
# 6                                        2    anesthesia         S
#
#         WARD_FACILITY_CODE BED_GRADE CITY_CODE_PATIENT TYPE_OF_ADMISSION  \
# CASE_ID
# 1                        F       2.0               7.0         Emergency
# 3                        E       2.0               7.0            Trauma
# 4                        D       2.0               7.0            Trauma
# 5                        D       2.0               7.0            Trauma
# 6                        F       2.0               7.0            Trauma
#
#         SEVERITY_OF_ILLNESS  VISITORS_WITH_PATIENT    AGE  ADMISSION_DEPOSIT  \
# CASE_ID
# 1                   Extreme                      2  51-60               4911
# 3                   Extreme                      2  51-60               4745
# 4                   Extreme                      2  51-60               7272
# 5                   Extreme                      2  51-60               5558
# 6                   Extreme                      2  51-60               4449
#
#         ADMISSION_YEAR ADMISSION_MONTH ADMISSION_DAY ADMISSION_MONTH_NAME  \
# CASE_ID
# 1                 2022               8            10               August
# 3                 2022               9             9            September
# 4                 2022               9            22            September
# 5                 2022              11             2             November
# 6                 2022               9            16            September
#
#         ADMISSION_DAY_NAME ADMISSION_ILLNESS_COMB ILLNESS_BEDGRADE_COMB  \
# CASE_ID
# 1                Wednesday      Emergency-Extreme           Extreme-2.0
# 3                   Friday         Trauma-Extreme           Extreme-2.0
# 4                 Thursday         Trauma-Extreme           Extreme-2.0
# 5                Wednesday         Trauma-Extreme           Extreme-2.0
# 6                   Friday         Trauma-Extreme           Extreme-2.0
#
#         DEPARTMENT_ILLNESS_COMB  LENGTH_OF_STAY STAY_DURATION
# CASE_ID
# 1          radiotherapy-Extreme              10   Medium Stay
# 3            anesthesia-Extreme              40     Long Stay
# 4          radiotherapy-Extreme              50     Long Stay
# 5          radiotherapy-Extreme              50     Long Stay
# 6            anesthesia-Extreme              20     Long Stay

# %%
print(score_data_processed.shape)
score_data_processed.head()
# Out:
# (236704, 188)
#          AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL  VISITORS_WITH_PATIENT  \
# CASE_ID
# 1                                        3                      2
# 3                                        2                      2
# 4                                        2                      2
# 5                                        2                      2
# 6                                        2                      2
#
#          ADMISSION_DEPOSIT  LENGTH_OF_STAY  HOSPITAL_TYPE_CODE_a  \
# CASE_ID
# 1                     4911              10                     0
# 3                     4745              40                     0
# 4                     7272              50                     0
# 5                     5558              50                     0
# 6                     4449              20                     1
#
#          HOSPITAL_TYPE_CODE_b  HOSPITAL_TYPE_CODE_c  HOSPITAL_TYPE_CODE_d  \
# CASE_ID
# 1                           0                     1                     0
# 3                           0                     0                     0
# 4                           1                     0                     0
# 5                           1                     0                     0
# 6                           0                     0                     0
#
#          HOSPITAL_TYPE_CODE_e  HOSPITAL_TYPE_CODE_f  HOSPITAL_TYPE_CODE_g  \
# CASE_ID
# 1                           0                     0                     0
# 3                           1                     0                     0
# 4                           0                     0                     0
# 5                           0                     0                     0
# 6                           0                     0                     0
#
#          CITY_CODE_HOSPITAL_1  CITY_CODE_HOSPITAL_2  CITY_CODE_HOSPITAL_3  \
# CASE_ID
# 1                           0                     0                     1
# 3                           1                     0                     0
# 4                           0                     1                     0
# 5                           0                     1                     0
# 6                           0                     0                     0
#
#          CITY_CODE_HOSPITAL_4  CITY_CODE_HOSPITAL_5  CITY_CODE_HOSPITAL_6  \
# CASE_ID
# 1                           0                     0                     0
# 3                           0                     0                     0
# 4                           0                     0                     0
# 5                           0                     0                     0
# 6                           0                     0                     1
#
#          CITY_CODE_HOSPITAL_7  CITY_CODE_HOSPITAL_9  CITY_CODE_HOSPITAL_10  \
# CASE_ID
# 1                           0                     0                      0
# 3                           0                     0                      0
# 4                           0                     0                      0
# 5                           0                     0                      0
# 6                           0                     0                      0
#
#          CITY_CODE_HOSPITAL_11  CITY_CODE_HOSPITAL_13  HOSPITAL_REGION_CODE_X  \
# CASE_ID
# 1                            0                      0                       0
# 3                            0                      0                       1
# 4                            0                      0                       0
# 5                            0                      0                       0
# 6                            0                      0                       1
#
#          HOSPITAL_REGION_CODE_Y  HOSPITAL_REGION_CODE_Z  \
# CASE_ID
# 1                             0                       1
# 3                             0                       0
# 4                             1                       0
# 5                             1                       0
# 6                             0                       0
#
#          DEPARTMENT_TB & Chest disease  DEPARTMENT_anesthesia  \
# CASE_ID
# 1                                    0                      0
# 3                                    0                      1
# 4                                    0                      0
# 5                                    0                      0
# 6                                    0                      1
#
#          DEPARTMENT_gynecology  DEPARTMENT_radiotherapy  DEPARTMENT_surgery  \
# CASE_ID
# 1                            0                        1                   0
# 3                            0                        0                   0
# 4                            0                        1                   0
# 5                            0                        1                   0
# 6                            0                        0                   0
#
#          WARD_TYPE_P  WARD_TYPE_Q  WARD_TYPE_R  WARD_TYPE_S  WARD_TYPE_T  \
# CASE_ID
# 1                  0            0            1            0            0
# 3                  0            0            0            1            0
# 4                  0            0            1            0            0
# 5                  0            0            0            1            0
# 6                  0            0            0            1            0
#
#          WARD_TYPE_U  WARD_FACILITY_CODE_A  WARD_FACILITY_CODE_B  \
# CASE_ID
# 1                  0                     0                     0
# 3                  0                     0                     0
# 4                  0                     0                     0
# 5                  0                     0                     0
# 6                  0                     0                     0
#
#          WARD_FACILITY_CODE_C  WARD_FACILITY_CODE_D  WARD_FACILITY_CODE_E  \
# CASE_ID
# 1                           0                     0                     0
# 3                           0                     0                     1
# 4                           0                     1                     0
# 5                           0                     1                     0
# 6                           0                     0                     0
#
#          WARD_FACILITY_CODE_F  BED_GRADE_0.0  BED_GRADE_1.0  BED_GRADE_2.0  \
# CASE_ID
# 1                           1              0              0              1
# 3                           0              0              0              1
# 4                           0              0              0              1
# 5                           0              0              0              1
# 6                           1              0              0              1
#
#          BED_GRADE_3.0  BED_GRADE_4.0  CITY_CODE_PATIENT_0.0  \
# CASE_ID
# 1                    0              0                      0
# 3                    0              0                      0
# 4                    0              0                      0
# 5                    0              0                      0
# 6                    0              0                      0
#
#          CITY_CODE_PATIENT_1.0  CITY_CODE_PATIENT_2.0  CITY_CODE_PATIENT_3.0  \
# CASE_ID
# 1                            0                      0                      0
# 3                            0                      0                      0
# 4                            0                      0                      0
# 5                            0                      0                      0
# 6                            0                      0                      0
#
#          CITY_CODE_PATIENT_4.0  CITY_CODE_PATIENT_5.0  CITY_CODE_PATIENT_6.0  \
# CASE_ID
# 1                            0                      0                      0
# 3                            0                      0                      0
# 4                            0                      0                      0
# 5                            0                      0                      0
# 6                            0                      0                      0
#
#          CITY_CODE_PATIENT_7.0  CITY_CODE_PATIENT_8.0  CITY_CODE_PATIENT_9.0  \
# CASE_ID
# 1                            1                      0                      0
# 3                            1                      0                      0
# 4                            1                      0                      0
# 5                            1                      0                      0
# 6                            1                      0                      0
#
#          CITY_CODE_PATIENT_10.0  CITY_CODE_PATIENT_11.0  \
# CASE_ID
# 1                             0                       0
# 3                             0                       0
# 4                             0                       0
# 5                             0                       0
# 6                             0                       0
#
#          CITY_CODE_PATIENT_12.0  CITY_CODE_PATIENT_13.0  \
# CASE_ID
# 1                             0                       0
# 3                             0                       0
# 4                             0                       0
# 5                             0                       0
# 6                             0                       0
#
#          CITY_CODE_PATIENT_14.0  CITY_CODE_PATIENT_15.0  \
# CASE_ID
# 1                             0                       0
# 3                             0                       0
# 4                             0                       0
# 5                             0                       0
# 6                             0                       0
#
#          CITY_CODE_PATIENT_16.0  CITY_CODE_PATIENT_18.0  \
# CASE_ID
# 1                             0                       0
# 3                             0                       0
# 4                             0                       0
# 5                             0                       0
# 6                             0                       0
#
#          CITY_CODE_PATIENT_19.0  CITY_CODE_PATIENT_20.0  \
# CASE_ID
# 1                             0                       0
# 3                             0                       0
# 4                             0                       0
# 5                             0                       0
# 6                             0                       0
#
#          CITY_CODE_PATIENT_21.0  CITY_CODE_PATIENT_22.0  \
# CASE_ID
# 1                             0                       0
# 3                             0                       0
# 4                             0                       0
# 5                             0                       0
# 6                             0                       0
#
#          CITY_CODE_PATIENT_23.0  CITY_CODE_PATIENT_24.0  \
# CASE_ID
# 1                             0                       0
# 3                             0                       0
# 4                             0                       0
# 5                             0                       0
# 6                             0                       0
#
#          CITY_CODE_PATIENT_25.0  CITY_CODE_PATIENT_26.0  \
# CASE_ID
# 1                             0                       0
# 3                             0                       0
# 4                             0                       0
# 5                             0                       0
# 6                             0                       0
#
#          CITY_CODE_PATIENT_27.0  CITY_CODE_PATIENT_28.0  \
# CASE_ID
# 1                             0                       0
# 3                             0                       0
# 4                             0                       0
# 5                             0                       0
# 6                             0                       0
#
#          CITY_CODE_PATIENT_29.0  CITY_CODE_PATIENT_30.0  \
# CASE_ID
# 1                             0                       0
# 3                             0                       0
# 4                             0                       0
# 5                             0                       0
# 6                             0                       0
#
#          CITY_CODE_PATIENT_31.0  CITY_CODE_PATIENT_32.0  \
# CASE_ID
# 1                             0                       0
# 3                             0                       0
# 4                             0                       0
# 5                             0                       0
# 6                             0                       0
#
#          CITY_CODE_PATIENT_33.0  CITY_CODE_PATIENT_34.0  \
# CASE_ID
# 1                             0                       0
# 3                             0                       0
# 4                             0                       0
# 5                             0                       0
# 6                             0                       0
#
#          CITY_CODE_PATIENT_35.0  CITY_CODE_PATIENT_36.0  \
# CASE_ID
# 1                             0                       0
# 3                             0                       0
# 4                             0                       0
# 5                             0                       0
# 6                             0                       0
#
#          CITY_CODE_PATIENT_37.0  TYPE_OF_ADMISSION_Emergency  \
# CASE_ID
# 1                             0                            1
# 3                             0                            0
# 4                             0                            0
# 5                             0                            0
# 6                             0                            0
#
#          TYPE_OF_ADMISSION_Trauma  TYPE_OF_ADMISSION_Urgent  \
# CASE_ID
# 1                               0                         0
# 3                               1                         0
# 4                               1                         0
# 5                               1                         0
# 6                               1                         0
#
#          SEVERITY_OF_ILLNESS_Extreme  SEVERITY_OF_ILLNESS_Minor  \
# CASE_ID
# 1                                  1                          0
# 3                                  1                          0
# 4                                  1                          0
# 5                                  1                          0
# 6                                  1                          0
#
#          SEVERITY_OF_ILLNESS_Moderate  AGE_0-10  AGE_20-Nov  AGE_21-30  \
# CASE_ID
# 1                                   0         0           0          0
# 3                                   0         0           0          0
# 4                                   0         0           0          0
# 5                                   0         0           0          0
# 6                                   0         0           0          0
#
#          AGE_31-40  AGE_41-50  AGE_51-60  AGE_61-70  AGE_71-80  AGE_81-90  \
# CASE_ID
# 1                0          0          1          0          0          0
# 3                0          0          1          0          0          0
# 4                0          0          1          0          0          0
# 5                0          0          1          0          0          0
# 6                0          0          1          0          0          0
#
#          AGE_91-100  ADMISSION_YEAR_2022  ADMISSION_MONTH_8  \
# CASE_ID
# 1                 0                    1                  1
# 3                 0                    1                  0
# 4                 0                    1                  0
# 5                 0                    1                  0
# 6                 0                    1                  0
#
#          ADMISSION_MONTH_9  ADMISSION_MONTH_10  ADMISSION_MONTH_11  \
# CASE_ID
# 1                        0                   0                   0
# 3                        1                   0                   0
# 4                        1                   0                   0
# 5                        0                   0                   1
# 6                        1                   0                   0
#
#          ADMISSION_DAY_1  ADMISSION_DAY_2  ADMISSION_DAY_3  ADMISSION_DAY_4  \
# CASE_ID
# 1                      0                0                0                0
# 3                      0                0                0                0
# 4                      0                0                0                0
# 5                      0                1                0                0
# 6                      0                0                0                0
#
#          ADMISSION_DAY_5  ADMISSION_DAY_6  ADMISSION_DAY_7  ADMISSION_DAY_8  \
# CASE_ID
# 1                      0                0                0                0
# 3                      0                0                0                0
# 4                      0                0                0                0
# 5                      0                0                0                0
# 6                      0                0                0                0
#
#          ADMISSION_DAY_9  ADMISSION_DAY_10  ADMISSION_DAY_11  \
# CASE_ID
# 1                      0                 1                 0
# 3                      1                 0                 0
# 4                      0                 0                 0
# 5                      0                 0                 0
# 6                      0                 0                 0
#
#          ADMISSION_DAY_12  ADMISSION_DAY_13  ADMISSION_DAY_14  \
# CASE_ID
# 1                       0                 0                 0
# 3                       0                 0                 0
# 4                       0                 0                 0
# 5                       0                 0                 0
# 6                       0                 0                 0
#
#          ADMISSION_DAY_15  ADMISSION_DAY_16  ADMISSION_DAY_17  \
# CASE_ID
# 1                       0                 0                 0
# 3                       0                 0                 0
# 4                       0                 0                 0
# 5                       0                 0                 0
# 6                       0                 1                 0
#
#          ADMISSION_DAY_18  ADMISSION_DAY_19  ADMISSION_DAY_20  \
# CASE_ID
# 1                       0                 0                 0
# 3                       0                 0                 0
# 4                       0                 0                 0
# 5                       0                 0                 0
# 6                       0                 0                 0
#
#          ADMISSION_DAY_21  ADMISSION_DAY_22  ADMISSION_DAY_23  \
# CASE_ID
# 1                       0                 0                 0
# 3                       0                 0                 0
# 4                       0                 1                 0
# 5                       0                 0                 0
# 6                       0                 0                 0
#
#          ADMISSION_DAY_24  ADMISSION_DAY_25  ADMISSION_DAY_26  \
# CASE_ID
# 1                       0                 0                 0
# 3                       0                 0                 0
# 4                       0                 0                 0
# 5                       0                 0                 0
# 6                       0                 0                 0
#
#          ADMISSION_DAY_27  ADMISSION_DAY_28  ADMISSION_DAY_29  \
# CASE_ID
# 1                       0                 0                 0
# 3                       0                 0                 0
# 4                       0                 0                 0
# 5                       0                 0                 0
# 6                       0                 0                 0
#
#          ADMISSION_DAY_30  ADMISSION_DAY_31  ADMISSION_MONTH_NAME_August  \
# CASE_ID
# 1                       0                 0                            1
# 3                       0                 0                            0
# 4                       0                 0                            0
# 5                       0                 0                            0
# 6                       0                 0                            0
#
#          ADMISSION_MONTH_NAME_November  ADMISSION_MONTH_NAME_October  \
# CASE_ID
# 1                                    0                             0
# 3                                    0                             0
# 4                                    0                             0
# 5                                    1                             0
# 6                                    0                             0
#
#          ADMISSION_MONTH_NAME_September  ADMISSION_DAY_NAME_Friday  \
# CASE_ID
# 1                                     0                          0
# 3                                     1                          1
# 4                                     1                          0
# 5                                     0                          0
# 6                                     1                          1
#
#          ADMISSION_DAY_NAME_Monday  ADMISSION_DAY_NAME_Saturday  \
# CASE_ID
# 1                                0                            0
# 3                                0                            0
# 4                                0                            0
# 5                                0                            0
# 6                                0                            0
#
#          ADMISSION_DAY_NAME_Sunday  ADMISSION_DAY_NAME_Thursday  \
# CASE_ID
# 1                                0                            0
# 3                                0                            0
# 4                                0                            1
# 5                                0                            0
# 6                                0                            0
#
#          ADMISSION_DAY_NAME_Tuesday  ADMISSION_DAY_NAME_Wednesday  \
# CASE_ID
# 1                                 0                             1
# 3                                 0                             0
# 4                                 0                             0
# 5                                 0                             1
# 6                                 0                             0
#
#          ADMISSION_ILLNESS_COMB_Emergency-Extreme  \
# CASE_ID
# 1                                               1
# 3                                               0
# 4                                               0
# 5                                               0
# 6                                               0
#
#          ADMISSION_ILLNESS_COMB_Emergency-Minor  \
# CASE_ID
# 1                                             0
# 3                                             0
# 4                                             0
# 5                                             0
# 6                                             0
#
#          ADMISSION_ILLNESS_COMB_Emergency-Moderate  \
# CASE_ID
# 1                                                0
# 3                                                0
# 4                                                0
# 5                                                0
# 6                                                0
#
#          ADMISSION_ILLNESS_COMB_Trauma-Extreme  \
# CASE_ID
# 1                                            0
# 3                                            1
# 4                                            1
# 5                                            1
# 6                                            1
#
#          ADMISSION_ILLNESS_COMB_Trauma-Minor  \
# CASE_ID
# 1                                          0
# 3                                          0
# 4                                          0
# 5                                          0
# 6                                          0
#
#          ADMISSION_ILLNESS_COMB_Trauma-Moderate  \
# CASE_ID
# 1                                             0
# 3                                             0
# 4                                             0
# 5                                             0
# 6                                             0
#
#          ADMISSION_ILLNESS_COMB_Urgent-Extreme  \
# CASE_ID
# 1                                            0
# 3                                            0
# 4                                            0
# 5                                            0
# 6                                            0
#
#          ADMISSION_ILLNESS_COMB_Urgent-Minor  \
# CASE_ID
# 1                                          0
# 3                                          0
# 4                                          0
# 5                                          0
# 6                                          0
#
#          ADMISSION_ILLNESS_COMB_Urgent-Moderate  \
# CASE_ID
# 1                                             0
# 3                                             0
# 4                                             0
# 5                                             0
# 6                                             0
#
#          ILLNESS_BEDGRADE_COMB_Extreme-0.0  ILLNESS_BEDGRADE_COMB_Extreme-1.0  \
# CASE_ID
# 1                                        0                                  0
# 3                                        0                                  0
# 4                                        0                                  0
# 5                                        0                                  0
# 6                                        0                                  0
#
#          ILLNESS_BEDGRADE_COMB_Extreme-2.0  ILLNESS_BEDGRADE_COMB_Extreme-3.0  \
# CASE_ID
# 1                                        1                                  0
# 3                                        1                                  0
# 4                                        1                                  0
# 5                                        1                                  0
# 6                                        1                                  0
#
#          ILLNESS_BEDGRADE_COMB_Extreme-4.0  ILLNESS_BEDGRADE_COMB_Minor-0.0  \
# CASE_ID
# 1                                        0                                0
# 3                                        0                                0
# 4                                        0                                0
# 5                                        0                                0
# 6                                        0                                0
#
#          ILLNESS_BEDGRADE_COMB_Minor-1.0  ILLNESS_BEDGRADE_COMB_Minor-2.0  \
# CASE_ID
# 1                                      0                                0
# 3                                      0                                0
# 4                                      0                                0
# 5                                      0                                0
# 6                                      0                                0
#
#          ILLNESS_BEDGRADE_COMB_Minor-3.0  ILLNESS_BEDGRADE_COMB_Minor-4.0  \
# CASE_ID
# 1                                      0                                0
# 3                                      0                                0
# 4                                      0                                0
# 5                                      0                                0
# 6                                      0                                0
#
#          ILLNESS_BEDGRADE_COMB_Moderate-0.0  \
# CASE_ID
# 1                                         0
# 3                                         0
# 4                                         0
# 5                                         0
# 6                                         0
#
#          ILLNESS_BEDGRADE_COMB_Moderate-1.0  \
# CASE_ID
# 1                                         0
# 3                                         0
# 4                                         0
# 5                                         0
# 6                                         0
#
#          ILLNESS_BEDGRADE_COMB_Moderate-2.0  \
# CASE_ID
# 1                                         0
# 3                                         0
# 4                                         0
# 5                                         0
# 6                                         0
#
#          ILLNESS_BEDGRADE_COMB_Moderate-3.0  \
# CASE_ID
# 1                                         0
# 3                                         0
# 4                                         0
# 5                                         0
# 6                                         0
#
#          ILLNESS_BEDGRADE_COMB_Moderate-4.0  \
# CASE_ID
# 1                                         0
# 3                                         0
# 4                                         0
# 5                                         0
# 6                                         0
#
#          DEPARTMENT_ILLNESS_COMB_TB & Chest disease-Extreme  \
# CASE_ID
# 1                                                        0
# 3                                                        0
# 4                                                        0
# 5                                                        0
# 6                                                        0
#
#          DEPARTMENT_ILLNESS_COMB_TB & Chest disease-Minor  \
# CASE_ID
# 1                                                       0
# 3                                                       0
# 4                                                       0
# 5                                                       0
# 6                                                       0
#
#          DEPARTMENT_ILLNESS_COMB_TB & Chest disease-Moderate  \
# CASE_ID
# 1                                                        0
# 3                                                        0
# 4                                                        0
# 5                                                        0
# 6                                                        0
#
#          DEPARTMENT_ILLNESS_COMB_anesthesia-Extreme  \
# CASE_ID
# 1                                                 0
# 3                                                 1
# 4                                                 0
# 5                                                 0
# 6                                                 1
#
#          DEPARTMENT_ILLNESS_COMB_anesthesia-Minor  \
# CASE_ID
# 1                                               0
# 3                                               0
# 4                                               0
# 5                                               0
# 6                                               0
#
#          DEPARTMENT_ILLNESS_COMB_anesthesia-Moderate  \
# CASE_ID
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 5                                                  0
# 6                                                  0
#
#          DEPARTMENT_ILLNESS_COMB_gynecology-Extreme  \
# CASE_ID
# 1                                                 0
# 3                                                 0
# 4                                                 0
# 5                                                 0
# 6                                                 0
#
#          DEPARTMENT_ILLNESS_COMB_gynecology-Minor  \
# CASE_ID
# 1                                               0
# 3                                               0
# 4                                               0
# 5                                               0
# 6                                               0
#
#          DEPARTMENT_ILLNESS_COMB_gynecology-Moderate  \
# CASE_ID
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 5                                                  0
# 6                                                  0
#
#          DEPARTMENT_ILLNESS_COMB_radiotherapy-Extreme  \
# CASE_ID
# 1                                                   1
# 3                                                   0
# 4                                                   1
# 5                                                   1
# 6                                                   0
#
#          DEPARTMENT_ILLNESS_COMB_radiotherapy-Minor  \
# CASE_ID
# 1                                                 0
# 3                                                 0
# 4                                                 0
# 5                                                 0
# 6                                                 0
#
#          DEPARTMENT_ILLNESS_COMB_radiotherapy-Moderate  \
# CASE_ID
# 1                                                    0
# 3                                                    0
# 4                                                    0
# 5                                                    0
# 6                                                    0
#
#          DEPARTMENT_ILLNESS_COMB_surgery-Extreme  \
# CASE_ID
# 1                                              0
# 3                                              0
# 4                                              0
# 5                                              0
# 6                                              0
#
#          DEPARTMENT_ILLNESS_COMB_surgery-Minor  \
# CASE_ID
# 1                                            0
# 3                                            0
# 4                                            0
# 5                                            0
# 6                                            0
#
#          DEPARTMENT_ILLNESS_COMB_surgery-Moderate  STAY_DURATION_Long Stay  \
# CASE_ID
# 1                                               0                        0
# 3                                               0                        1
# 4                                               0                        1
# 5                                               0                        1
# 6                                               0                        1
#
#          STAY_DURATION_Medium Stay
# CASE_ID
# 1                                1
# 3                                0
# 4                                0
# 5                                0
# 6                                0

# %%
print(score_data_final.shape)
score_data_final.head()
# Out:
# (236704, 21)
#    index  CASE_ID  TYPE_OF_ADMISSION_Emergency  AGE_41-50  \
# 0      0        1                            1          0
# 1      1        3                            0          0
# 2      2        4                            0          0
# 3      3        5                            0          0
# 4      4        6                            0          0
#
#    CITY_CODE_HOSPITAL_7  VISITORS_WITH_PATIENT  WARD_TYPE_S  \
# 0                     0                      2            0
# 1                     0                      2            1
# 2                     0                      2            0
# 3                     0                      2            1
# 4                     0                      2            1
#
#    ADMISSION_MONTH_NAME_November  TYPE_OF_ADMISSION_Trauma  \
# 0                              0                         0
# 1                              0                         1
# 2                              0                         1
# 3                              1                         1
# 4                              0                         1
#
#    ADMISSION_MONTH_11  CITY_CODE_HOSPITAL_2  WARD_TYPE_P  \
# 0                   0                     0            0
# 1                   0                     0            0
# 2                   0                     1            0
# 3                   1                     1            0
# 4                   0                     0            0
#
#    STAY_DURATION_Long Stay  ADMISSION_DEPOSIT  ADMISSION_MONTH_10  \
# 0                        0               4911                   0
# 1                        1               4745                   0
# 2                        1               7272                   0
# 3                        1               5558                   0
# 4                        1               4449                   0
#
#    SEVERITY_OF_ILLNESS_Minor  WARD_TYPE_Q  STAY_DURATION_Medium Stay  \
# 0                          0            0                          1
# 1                          0            0                          0
# 2                          0            0                          0
# 3                          0            0                          0
# 4                          0            0                          0
#
#    AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL  LENGTH_OF_STAY  PREDICTED_LOS
# 0                                  3              10           10.0
# 1                                  2              40           33.0
# 2                                  2              50           35.0
# 3                                  2              50           30.0
# 4                                  2              20           35.0

# %%
print(score_data_table.shape)
score_data_table.head()
# Out:
# (236704, 45)
#    CASE_ID HOSPITAL_TYPE_CODE CITY_CODE_HOSPITAL HOSPITAL_REGION_CODE  \
# 0        1                  c                  3                    Z
# 1        3                  e                  1                    X
# 2        4                  b                  2                    Y
# 3        5                  b                  2                    Y
# 4        6                  a                  6                    X
#
#    AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL_x    DEPARTMENT WARD_TYPE  \
# 0                                    3  radiotherapy         R
# 1                                    2    anesthesia         S
# 2                                    2  radiotherapy         R
# 3                                    2  radiotherapy         S
# 4                                    2    anesthesia         S
#
#   WARD_FACILITY_CODE BED_GRADE CITY_CODE_PATIENT TYPE_OF_ADMISSION  \
# 0                  F       2.0               7.0         Emergency
# 1                  E       2.0               7.0            Trauma
# 2                  D       2.0               7.0            Trauma
# 3                  D       2.0               7.0            Trauma
# 4                  F       2.0               7.0            Trauma
#
#   SEVERITY_OF_ILLNESS  VISITORS_WITH_PATIENT_x    AGE  ADMISSION_DEPOSIT_x  \
# 0             Extreme                        2  51-60                 4911
# 1             Extreme                        2  51-60                 4745
# 2             Extreme                        2  51-60                 7272
# 3             Extreme                        2  51-60                 5558
# 4             Extreme                        2  51-60                 4449
#
#   ADMISSION_YEAR ADMISSION_MONTH ADMISSION_DAY ADMISSION_MONTH_NAME  \
# 0           2022               8            10               August
# 1           2022               9             9            September
# 2           2022               9            22            September
# 3           2022              11             2             November
# 4           2022               9            16            September
#
#   ADMISSION_DAY_NAME ADMISSION_ILLNESS_COMB ILLNESS_BEDGRADE_COMB  \
# 0          Wednesday      Emergency-Extreme           Extreme-2.0
# 1             Friday         Trauma-Extreme           Extreme-2.0
# 2           Thursday         Trauma-Extreme           Extreme-2.0
# 3          Wednesday         Trauma-Extreme           Extreme-2.0
# 4             Friday         Trauma-Extreme           Extreme-2.0
#
#   DEPARTMENT_ILLNESS_COMB  LENGTH_OF_STAY_x STAY_DURATION  index  \
# 0    radiotherapy-Extreme                10   Medium Stay      0
# 1      anesthesia-Extreme                40     Long Stay      1
# 2    radiotherapy-Extreme                50     Long Stay      2
# 3    radiotherapy-Extreme                50     Long Stay      3
# 4      anesthesia-Extreme                20     Long Stay      4
#
#    TYPE_OF_ADMISSION_Emergency  AGE_41-50  CITY_CODE_HOSPITAL_7  \
# 0                            1          0                     0
# 1                            0          0                     0
# 2                            0          0                     0
# 3                            0          0                     0
# 4                            0          0                     0
#
#    VISITORS_WITH_PATIENT_y  WARD_TYPE_S  ADMISSION_MONTH_NAME_November  \
# 0                        2            0                              0
# 1                        2            1                              0
# 2                        2            0                              0
# 3                        2            1                              1
# 4                        2            1                              0
#
#    TYPE_OF_ADMISSION_Trauma  ADMISSION_MONTH_11  CITY_CODE_HOSPITAL_2  \
# 0                         0                   0                     0
# 1                         1                   0                     0
# 2                         1                   0                     1
# 3                         1                   1                     1
# 4                         1                   0                     0
#
#    WARD_TYPE_P  STAY_DURATION_Long Stay  ADMISSION_DEPOSIT_y  \
# 0            0                        0                 4911
# 1            0                        1                 4745
# 2            0                        1                 7272
# 3            0                        1                 5558
# 4            0                        1                 4449
#
#    ADMISSION_MONTH_10  SEVERITY_OF_ILLNESS_Minor  WARD_TYPE_Q  \
# 0                   0                          0            0
# 1                   0                          0            0
# 2                   0                          0            0
# 3                   0                          0            0
# 4                   0                          0            0
#
#    STAY_DURATION_Medium Stay  AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL_y  \
# 0                          1                                    3
# 1                          0                                    2
# 2                          0                                    2
# 3                          0                                    2
# 4                          0                                    2
#
#    LENGTH_OF_STAY_y  PREDICTED_LOS
# 0                10           10.0
# 1                40           33.0
# 2                50           35.0
# 3                50           30.0
# 4                20           35.0
